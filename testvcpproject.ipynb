# %% [markdown]
# # [Retrieval-based-Voice-Conversion-WebUI](https://github.com/RVC-Project/Retrieval-based-Voice-Conversion-WebUI) Training notebook

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/RVC-Project/Retrieval-based-Voice-Conversion-WebUI/blob/main/Retrieval_based_Voice_Conversion_WebUI.ipynb)

# %%
# !git clone https://github.com/ihalder1/testvcproject.git -b testfeature

# !wget -q https://repo.anaconda.com/miniconda/Miniconda3-py38_4.12.0-Linux-x86_64.sh
# !chmod +x Miniconda3-py38_4.12.0-Linux-x86_64.sh
# !./Miniconda3-py38_4.12.0-Linux-x86_64.sh -b -f -p /usr/local

# !conda create -n py38 python=3.8 -y
# !conda init bash
# !conda update -n base -c defaults conda -y

# %%
import sys
sys.path.append('/usr/local/lib/python3.8/site-packages/')
# !source /usr/local/etc/profile.d/conda.sh && conda activate py38

# %%
# %cd /content/testvcproject/
# !sudo apt-get update && sudo apt-get install -y aria2

# !sudo apt-get install -y make build-essential libssl-dev zlib1g-dev \
libbz2-dev libreadline-dev libsqlite3-dev wget curl llvm \
libncursesw5-dev xz-utils tk-dev libxml2-dev libxmlsec1-dev libffi-dev liblzma-dev

# 2. Install pyenv
# !curl https://pyenv.run | bash

# 3. Add to PATH (for current session)
import os
os.environ['PATH'] = f"/root/.pyenv/bin:{os.environ['PATH']}"

# 4. Verify
# !pyenv --version

# %%
# !conda install -c anaconda portaudio -y

# !conda install -c conda-forge cudatoolkit=11.8 -y

# !conda install -c conda-forge pip -y
# !pip install pyngrok
# !pip install ipython

# %%
# %cd testvcproject
# !ngrok config add-authtoken xyz
# !./run.sh
